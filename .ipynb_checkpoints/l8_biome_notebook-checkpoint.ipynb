# %% [markdown]
# # Importing dataset

# %%
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
import numpy as np
import os
import io
import pandas as pd
import cv2
import sklearn
import random
from osgeo import gdal
import shutil

# %% [markdown]
# # PATHS

# %%
DATA_PATH = "D:/Geoprocessamento/DataSetModelo/l8_biome/"

SCENES_PATH = DATA_PATH + "BC/"

# %% [markdown]
# # Metadata

# %%
metadata = pd.read_csv(DATA_PATH + 'Meta_Data.csv')
metadata["Manual CCA"] = metadata["Manual CCA"].str.rstrip('%').astype('float')
metadata
# Out:
#        Biome    Scene ID (Level-1T)  Path  Row Acquisition Date  \
# 0     Barren  LC80420082013220LGN00    42    8         8/8/2013
# 1     Barren  LC80500092014231LGN00    50    9        8/19/2014
# 2     Barren  LC80530022014156LGN00    53    2         6/5/2014
# 3     Barren  LC81330312013202LGN00   133   31        7/21/2013
# 4     Barren  LC81360302014162LGN00   136   30        6/11/2014
# ..       ...                    ...   ...  ...              ...
# 91  Wetlands  LC81080182014238LGN00   108   18        8/26/2014
# 92  Wetlands  LC81460162014168LGN00   146   16        6/17/2014
# 93  Wetlands  LC81500152013225LGN00   150   15        8/13/2013
# 94  Wetlands  LC81580172013201LGN00   158   17        7/20/2013
# 95  Wetlands  LC81750732014035LGN00   175   73         2/4/2014
#
#    Approximate Cloud Status Shadows?  Manual CCA
# 0                     Clear       no        0.00
# 1                    Cloudy       no       98.13
# ...

# %%
metadata["Manual CCA"].hist()
plt.xticks(rotation=65)
plt.show()

# %%
print(type(metadata["Manual CCA"][0]))
# Out:
# <class 'numpy.float64'>

# %%
metadata['cloud_percent_cat'] = pd.cut(metadata['Manual CCA'], 
                               bins=[-np.inf,25.,50.,75.,np.inf], 
                                     labels = [1,2,3,4]
                                   )

# %%
plt.figure(figsize=(8, 4))
plt.title('Cloud Cover distribution')
metadata['cloud_percent_cat'].hist()
plt.xlabel('Cloud cover percentage')
plt.ylabel('Number of images')
plt.grid(False)
plt.savefig('distribution.png')
plt.show()

# %%
#Divide o dataset uniformemente
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
#Divide 70 30
for train_index, test_index in split.split(metadata, metadata['cloud_percent_cat']):
    strat_train_set = metadata.loc[train_index]
    strat_val_set = metadata.loc[test_index]
#Divide 30 em 90 10
split = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=8)
for test_index, val_index in split.split(strat_val_set, strat_val_set['cloud_percent_cat']):
    strat_test_set = metadata.loc[test_index]
    strat_val_set = metadata.loc[val_index]

# %%
#PEGA LISTA DOS ARQUIVOS DE TREINO
train_files = []
val_files = []
test_files = []
for index, file in strat_train_set.iterrows():
    train_files.append(file['Scene ID (Level-1T)'])
    
for index, file in strat_val_set.iterrows():
    val_files.append(file['Scene ID (Level-1T)'])
    
for index, file in strat_test_set.iterrows():
    test_files.append(file['Scene ID (Level-1T)'])

# %% [markdown]
# # Utils

# %%
def normalize_min_max(image):
    return((image-np.nanmin(image))/(np.nanmax(image)- np.nanmin(image)))

def resize_img(image,x,y,z):
    image = cv2.resize(image,(x,y))
    image = image.reshape((x,y,z))
    return image

def clip_image(r,g,b,n):
    return np.dstack((r,g,b,n))

def print_l8_biome_image(image):
    plt.figure()
    plt.imshow(image)
    plt.show()

# %% [markdown]
# # Separando o dataset em diretórios

# %%
# Creating folders
try:
    folders = ['train_frames', 'train_masks', 'val_frames', 'val_masks', 'test_frames', 'test_masks']
    for folder in folders:
        os.makedirs(DATA_PATH + folder)
except:
    pass

# %%
#Split dataset files
"""
all_frames = os.listdir(SCENES_PATH)
random.seed(4)
random.shuffle(all_frames,)

train_size = int(0.7 * len(all_frames))
val_size = int(0.15 * len(all_frames))
test_size = int(0.15 * len(all_frames))

train_scene = all_frames[:train_size]
val_scene = all_frames[train_size:train_size+val_size]
test_scene = val_subscenes = all_frames[train_size+val_size:]
"""
# Out:
# '\nall_frames = os.listdir(SCENES_PATH)\nrandom.seed(4)\nrandom.shuffle(all_frames,)\n\ntrain_size = int(0.7 * len(all_frames))\nval_size = int(0.15 * len(all_frames))\ntest_size = int(0.15 * len(all_frames))\n\ntrain_scene = all_frames[:train_size]\nval_scene = all_frames[train_size:train_size+val_size]\ntest_scene = val_subscenes = all_frames[train_size+val_size:]\n'

# %%
all_frames = os.listdir(SCENES_PATH)

# %%
# Generate corresponding mask lists for masks
train_masks = [f for f in all_frames if f in train_files]
val_masks = [f for f in all_frames if f in val_files]
test_masks = [f for f in all_frames if f in test_files]

# %% [markdown]
# #teste

# %%
image = 'LC80150312014226LGN00'

# %%
dir_name = 'D:/Geoprocessamento/DataSetModelo/l8_biome/' +  'BC/'
current_dir_r = SCENES_PATH + image +'/'+ image + '_B3.TIF'
current_dir_g = SCENES_PATH + image +'/'+ image + '_B2.TIF'
current_dir_b = SCENES_PATH + image +'/'+ image + '_B1.TIF'
current_dir_NIR = SCENES_PATH + image +'/'+ image + '_B4.TIF'
current_dir_MASK = SCENES_PATH + image +'/'+ image + '_fixedmask.img'
mask = gdal.Open(current_dir_MASK)
r = gdal.Open(current_dir_r)
g = gdal.Open(current_dir_g)
b = gdal.Open(current_dir_b)
n = gdal.Open(current_dir_NIR)

# %%
teste = gdal.Open("teste/27_13.TIF").ReadAsArray()

# %%
image

# %%
output_dir = "teste/"

# %%
teste = np.load("teste/rgbn623.npy")
np.nanmin(teste)

# %%
crop_image_rgb(output_dir,image, r,g,b,n, gt, 256)

# %%
#Essa funcao corta as imagens RGB e clipa as mesmas num unico arquivo .npy
def crop_image_rgb(output_dir, image_name, r, g, b, n, gt, dimension):
    #gt = r.GetGeoTransform()
    x_min = gt[0]
    y_max = gt[3]
    
    res = gt[1]
    
    num_img_x = r.RasterXSize/dimension
    num_img_y = r.RasterYSize/dimension
    
    x_len = res * r.RasterXSize
    y_len = res * r.RasterYSize
    
    x_size = x_len/num_img_x
    y_size = y_len/num_img_y


    x_steps = [x_min + x_size * i for i in range(int(num_img_x) + 1)]
    y_steps = [y_max - y_size * i for i in range(int(num_img_y) + 1)]
    print("qnt img: " + str(num_img_y))

    for i in range(int(min(num_img_x,num_img_y))):
        for j in range(int(min(num_img_x,num_img_y))):
            x_min = x_steps[i]
            x_max = x_steps[i+1]
            y_max = y_steps[j]
            y_min = y_steps[j+1]
            
            #D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/tif_files/LC80010732013109LGN00_1_0_r.TIF
            
            print(output_dir + 'tif_files/' + image_name + '_' + str(i)+ "_" +str(j)+'_r.TIF')
            #gdal.Warp(output_dir + str(i)+str(j)+'.TIF', image, outputBounds = (x_min,y_min,x_max, y_max), dstNodata = -9999)
            gdal.Warp(output_dir + 'tif_files/' + image_name + '_' + str(i)+ "_" +str(j)+'_r.TIF', r, outputBounds = (x_min,y_min,x_max, y_max), dstNodata = -9999)
            gdal.Warp(output_dir + 'tif_files/' + image_name + '_' + str(i)+ "_" +str(j)+'_g.TIF', g, outputBounds = (x_min,y_min,x_max, y_max), dstNodata = -9999)
            gdal.Warp(output_dir + 'tif_files/' + image_name + '_' + str(i)+ "_" +str(j)+'_b.TIF', b, outputBounds = (x_min,y_min,x_max, y_max), dstNodata = -9999)
            gdal.Warp(output_dir + 'tif_files/' + image_name + '_' + str(i)+ "_" +str(j)+'_n.TIF', n, outputBounds = (x_min,y_min,x_max, y_max), dstNodata = -9999)
             
            #Clip image
            r_atual_file = gdal.Open(output_dir + 'tif_files/' + image_name + '_' + str(i)+ "_" +str(j)+'_r.TIF').ReadAsArray()
            g_atual_file = gdal.Open(output_dir + 'tif_files/' + image_name + '_' + str(i)+ "_" +str(j)+'_g.TIF').ReadAsArray()
            b_atual_file = gdal.Open(output_dir + 'tif_files/' + image_name + '_' + str(i)+ "_" +str(j)+'_b.TIF').ReadAsArray()
            n_atual_file = gdal.Open(output_dir + 'tif_files/' + image_name + '_' + str(i)+ "_" +str(j)+'_n.TIF').ReadAsArray()
            rgbn = clip_image(r_atual_file, g_atual_file, b_atual_file, n_atual_file)
            print(output_dir + image_name + '_' + str(i)+ "_" + str(j) + '.npy')
            save(output_dir + image_name + '_' + str(i)+ "_" + str(j) + '.npy', rgbn)

# %%
def crop_mask(output_dir,image_name, image, gt, dimension):
    
    image.SetGeoTransform(gt)
    x_min = gt[0]
    y_max = gt[3]
    
    res = gt[1]
    
    num_img_x = image.RasterXSize/dimension
    num_img_y = image.RasterYSize/dimension
    
    x_len = res * image.RasterXSize
    y_len = res * image.RasterYSize
    
    x_size = x_len/num_img_x
    y_size = y_len/num_img_y
    


    x_steps = [x_min + x_size * i for i in range(int(num_img_x) + 1)]
    y_steps = [y_max - y_size * i for i in range(int(num_img_y) + 1)]
    print("qnt img: " + str(num_img_y))

    for i in range(int(min(num_img_x,num_img_y))):
        for j in range(int(min(num_img_x,num_img_y))):
            x_min = x_steps[i]
            x_max = x_steps[i+1]
            y_max = y_steps[j]
            y_min = y_steps[j+1]
            #D:/Geoprocessamento/DataSetModelo/l8_biome/val_masks/LC80200462014005LGN00tif_files/LC80200462014005LGN00_0_0.TIF
            print(output_dir + image_name + '_' + str(i)+ "_" +str(j)+'.npy')
            gdal.Warp(output_dir + image_name + '_' + str(i)+ "_" +str(j)+'.TIF', image, outputBounds = (x_min,y_min,x_max, y_max), dstNodata = -9999)

# %%
#Add train, val frames and masks to relevant folders
from numpy import save

def add_frames(dir_name, image):
    try:
        dir_name = 'D:/Geoprocessamento/DataSetModelo/l8_biome/' + dir_name + '/'
        current_dir_r = SCENES_PATH + image +'/'+ image + '_B3.TIF'
        current_dir_g = SCENES_PATH + image +'/'+ image + '_B2.TIF'
        current_dir_b = SCENES_PATH + image +'/'+ image + '_B1.TIF'
        current_dir_NIR = SCENES_PATH + image +'/'+ image + '_B4.TIF'
        #clip Image
        #r = gdal.Open(current_dir_r).ReadAsArray()
        #g = gdal.Open(current_dir_g).ReadAsArray()
        #b = gdal.Open(current_dir_b).ReadAsArray()
        #n = gdal.Open(current_dir_NIR).ReadAsArray()
        #rgbn = clip_image(r,g,b,n)
        #save(dir_name + image + '.npy', rgbn)
        
        #crop Images
        r = gdal.Open(current_dir_r)
        g = gdal.Open(current_dir_g)
        b = gdal.Open(current_dir_b)
        n = gdal.Open(current_dir_NIR)

        

        #D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/LC81620432014072LGN00_r
        #crop_image(dir_name + image + "_r", r, gt, 256)
        #crop_image(dir_name + image + "_g", g, gt, 256)
        #crop_image(dir_name + image + "_b", b, gt, 256)
        #crop_image(dir_name + image + "_n", n, gt, 256)
        gt = r.GetGeoTransform()
        crop_image_rgb(dir_name,image, r, g, b, n, gt, 256)
        
    except Exception as e: 
        print(e)
        pass
    
def add_masks(dir_name, image_name):
    try:
        dir_name = 'D:/Geoprocessamento/DataSetModelo/l8_biome/' + dir_name + '/'
        current_dir_MASK = SCENES_PATH + image_name +'/'+ image_name + '_fixedmask.img'
        
        print(current_dir_MASK)
    
        mask = gdal.Open(current_dir_MASK)
        
        #carrega imagem apenas para pegar o geotransform dela e passar para a mascara
        current_dir_r = SCENES_PATH + image_name +'/'+ image_name + '_B1.TIF'

        img_aux = gdal.Open(current_dir_r)
        gt = img_aux.GetGeoTransform()
        mask.SetGeoTransform(gt)
        
        crop_mask(dir_name,image_name, mask, gt, 256)
        
        #save(dir_name + image_name + '.npy', mask)
    except Exception as e:
        print(e)
        pass

# %%
frame_folders = [(train_files, 'train_frames'), (val_files, 'val_frames'), (test_files, 'test_frames')]

mask_folders = [(train_masks, 'train_masks'), (val_masks, 'val_masks'), (test_masks, 'test_masks')]

# %%
#Celula que carrega as imagens nos diretórios corretos

from PIL import Image

# Add frames
for folder in frame_folders:
    array = folder[0]
    name = [folder[1]] * len(array)
    list(map(add_frames, name, array))

# Add masks
for folder in mask_folders:
    array = folder[0]
    name = [folder[1]] * len(array)
    list(map(add_masks, name, array))
# Out:
# 'NoneType' object has no attribute 'GetGeoTransform'
# qnt img: 28.55859375
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/tif_files/LC80010732013109LGN00_0_0_r.TIF
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/LC80010732013109LGN00_0_0.npy
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/tif_files/LC80010732013109LGN00_0_1_r.TIF
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/LC80010732013109LGN00_0_1.npy
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/tif_files/LC80010732013109LGN00_0_2_r.TIF
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/LC80010732013109LGN00_0_2.npy
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/tif_files/LC80010732013109LGN00_0_3_r.TIF
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/LC80010732013109LGN00_0_3.npy
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames/tif_files/LC80010732013109LGN00_0_4_r.TIF
# ...

# %% [markdown]
# # Creating the generator

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        data_format=None,
        )

# %%
BATCH_SIZE = 4

train_image_generator = train_datagen.flow_from_directory(
'D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames',
batch_size = BATCH_SIZE)
# Out:
# Found 32820 images belonging to 1 classes.

# %%
import cv2
import random
from sklearn.model_selection import ParameterGrid

# %%
def data_gen(img_folder, mask_folder, batch_size):
    c = 0
    n = os.listdir(img_folder) #List of training images
    random.shuffle(n)
    x,y,z = 256,256,1
    while(True):
        img = np.zeros((batch_size, 256, 256, 4)).astype('float')
        mask = np.zeros((batch_size, 256, 256, 1)).astype('float')

        for i in range(c, c + batch_size): #initially from 0 to 16, c = 0. 
            train_img = np.load(img_folder+'/'+n[i], allow_pickle=True)
            
            
            train_img =  cv2.resize(train_img, (256, 256))# Read an image from folder and resize
            #train_img = train_img.reshape(256, 256, 4)
            train_img = normalize_min_max(train_img)
            train_img = tf.convert_to_tensor(train_img)
            img[i-c] = train_img #add to array - img[0], img[1], and so on.

            n[i] = n[i][:-3] + "TIF"
            
            print(mask_folder+'/'+n[i])
            train_mask = gdal.Open(mask_folder+'/'+n[i]).ReadAsArray()
            #train_mask = (np.load(mask_folder+'/'+n[i]))
            train_mask = train_mask/1
            #train_mask = cv2.resize(train_mask, (256, 256))
            train_mask = resize_img(train_mask,x,y,z)
            train_mask = normalize_min_max(train_mask)
            #train_mask = np.expand_dims(train_mask,axis=2)
            train_mask = tf.convert_to_tensor(train_mask)
            mask[i-c] = train_mask
            

        c += batch_size
        
        if(c + batch_size >= len(os.listdir(img_folder))):
            c=0
            random.shuffle(n)
                      # print "randomizing again"
        
        yield img, mask

train_frame_path = 'D:/Geoprocessamento/DataSetModelo/l8_biome/train_frames'
train_mask_path = 'D:/Geoprocessamento/DataSetModelo/l8_biome/train_masks'

val_frame_path = 'D:/Geoprocessamento/DataSetModelo/l8_biome/val_frames'
val_mask_path = 'D:/Geoprocessamento/DataSetModelo/l8_biome/val_masks'

test_frame_path = 'D:/Geoprocessamento/DataSetModelo/l8_biome/test_frames'
test_mask_path = 'D:/Geoprocessamento/DataSetModelo/l8_biome/test_masks'

train_gen = data_gen(train_frame_path,train_mask_path, batch_size = BATCH_SIZE)
val_gen = data_gen(val_frame_path,val_mask_path, batch_size = BATCH_SIZE)
test_gen = data_gen(test_frame_path,test_mask_path, batch_size = BATCH_SIZE)

# %% [markdown]
# # F1 SCORE

# %%
from keras import backend as K

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# # Creating the model

# %%
from keras.callbacks import ModelCheckpoint
from keras.callbacks import CSVLogger
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam

# %%
NO_OF_TRAINING_IMAGES = len(os.listdir(train_frame_path))
NO_OF_VAL_IMAGES = len(os.listdir(val_frame_path))
weights_path = 'D:/Geoprocessamento/DataSetModelo/l8_biome/'

checkpoint = ModelCheckpoint(weights_path, monitor='f1', 
                             verbose=1, save_best_only=True, mode='max')

csv_logger = CSVLogger('D:/Geoprocessamento/DataSetModelo/l8_biome/log.out', append=True, separator=';')

earlystopping = EarlyStopping(monitor = 'f1', verbose = 1,
                              min_delta = 0.01, patience = 20, mode = 'max')

callbacks_list = [checkpoint, csv_logger, earlystopping]

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

from itertools import chain
from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

# %%
# Build U-Net model

inputs = Input((256, 256, 4))
s = (inputs)

c1 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy",f1])
model.summary()
# Out:
# Model: "functional_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_6 (InputLayer)            [(None, 256, 256, 4) 0
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 256, 256, 32) 1184        input_6[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 256, 256, 32) 0           conv2d_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 256, 256, 32) 9248        dropout_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 128, 128, 32) 0           conv2d_96[0][0]
# ...

# %%
# !pip install visualkeras

# %%
import visualkeras
from tensorflow.python.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, ZeroPadding2D
from collections import defaultdict


visualkeras.layered_view(model,legend=True, scale_xy=0.5, scale_z=0.5, max_z=7, to_file='network.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=750x207 at 0x221B14FBB80>

# %% [markdown]
# ### Training

# %%
#training the model
model_history = model.fit(train_gen, 
                    epochs = 64, 
                    batch_size = BATCH_SIZE, 
                    validation_data = val_gen, 
                    callbacks = callbacks_list,
                    steps_per_epoch =(NO_OF_TRAINING_IMAGES/BATCH_SIZE), 
                    validation_steps = (NO_OF_VAL_IMAGES/BATCH_SIZE)
                  )
# Out:
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_masks/LC80160502014041LGN00_14_26.TIF
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_masks/LC80160502014041LGN00_9_22.TIF
# <ipython-input-31-5c7c9fc85302>:2: RuntimeWarning: invalid value encountered in true_divide
#   return((image-np.nanmin(image))/(np.nanmax(image)- np.nanmin(image)))
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_masks/LC80120552013202LGN00_26_24.TIF
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_masks/LC80170312013157LGN00_1_13.TIF
# Epoch 1/64
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_masks/LC80210072014236LGN00_21_33.TIF
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_masks/LC80010112014080LGN00_9_15.TIF
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_masks/LC80010732013109LGN00_17_7.TIF
# D:/Geoprocessamento/DataSetModelo/l8_biome/train_masks/LC80200462014005LGN00_10_22.TIF
# ...

# %%
from IPython.display import Image, display
import PIL
from PIL import ImageOps


def get_test_batch(qnt_images):
    evaluate = []
    
    convert_to_image = keras.preprocessing.image.array_to_img
    dir_images = test_frame_path
    dir_masks = test_mask_path
    test_files = os.listdir(test_frame_path)
    #batch_images_structure
    mask_true_image_test = np.zeros((qnt_images,512,512,1))
    batch_test_images = np.zeros((qnt_images,512,512,4))

    for i in range(qnt_images):
        mask_test = np.load(dir_masks + '/'+ test_files[i], allow_pickle=True)
        mask_test = mask_test / 1
        mask_test = cv2.resize(mask_test, (512,512))
        mask_test = np.expand_dims(mask_test,axis=2)
        mask_test = normalize_min_max(mask_test)
        
        imagem_teste = np.load(dir_images + '/'+ test_files[i],allow_pickle=True)
        imagem_teste = cv2.resize(imagem_teste, (512, 512))
        imagem_teste = cv2.resize(imagem_teste, (512, 512))
        imagem_teste = normalize_min_max(imagem_teste)
        
        y_eval = np.expand_dims(mask_test, axis=0)
        x_eval = np.expand_dims(imagem_teste, axis=0)
        
        evaluate.append(model.evaluate(x=x_eval,y=y_eval))
        
        mask_true_image_test [i,:,:] = mask_test
        batch_test_images [i,:,:] = imagem_teste
    return batch_test_images, mask_true_image_test, evaluate

# %%
qnt_images = 15
batch_test_images, mask_true_image_test, evaluate = get_test_batch(qnt_images)

# %%
df_eval = pd.DataFrame(evaluate)
df_eval.columns = ["Loss", "Accuracy", "f1"]
df_eval

# %%
print( 'Loss: ' + str(df_eval['Loss'].mean()))
print( 'F1: ' + str(df_eval['f1'].mean()))
print( 'Accuracy: ' + str(df_eval['Accuracy'].mean()))

# %%
mask_predict = model.predict(batch_test_images)

# %%
def show_images(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
        
    plt.show()

# %%
for i in range(qnt_images):
    b, g, r    = batch_test_images[i][:, :, 1], batch_test_images[i][:, :, 2], batch_test_images[i][:, :, 3]
    rgb = np.dstack((r,g,b))
    show_images([rgb, mask_true_image_test[i], mask_predict[i]])

# %% [markdown]
# # Aprendizado

# %%
acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']


plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.show()

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']


plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.ylabel('Loss')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Loss')

plt.show()

# %%
f1 = model_history.history['f1']
val_f1 = model_history.history['val_f1']


plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(f1, label='Training F1-Score')
plt.plot(val_f1, label='Validation F1-Score')
plt.legend(loc='lower right')
plt.ylabel('F1-Score')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation F1-Score')

plt.show()
